# %% [markdown]
# # GTA 666 : NLP & Sentiment Analysis

# %% [markdown]
# Scenario: You are working on a Data team at Rockstar Labs. A stakeholder from R&D has a request of trying to understand user feedback to determine any new features or upgrades the upcoming GTA 666 game should have.
#
# 1) Who is our community, what are their demographics & distribution of gamers Method to Use : Exploratory Data Analysis (EDA)
#
# 2)What are these people saying ? What is the most common request ? Method to use: Natural Language Processing Techniques
#
# 3)Determine the sentiment of the comment (are the positive? Are they negative ?) Method to use: Sentiment Analysis

# %%
## Import necessary packages
import pandas as pd
import numpy as np
import re
import nltk
import string
##from nltk.corpus import stopwords
##pip install pandas nltk textblob matplotlib

# %%
## Import Dataset , make sure upload your csv file in google colab first, then right click file to copy path
##from google.colab import files
##uploaded = files.upload()
df= pd.read_csv('/content/GTA666_subset.csv')

# %% [markdown]
# ## Exploritory Data Analysis (EDA)

# %%
# look at uploaded dataset top 10 rows

df.head(10)
# Out:
#              Timestamp            Name                      Email   Age  \
# 0  12/18/2023 21:17:05        jeb bush                        NaN   NaN
# 1                  NaN  Heather Savage      alvarezerin@gmail.com  25.0
# 2                  NaN         Ann Gay  rebeccafleming@wilson.com  54.0
# 3                  NaN    Rachel Parks   montoyashelley@gmail.com  55.0
# 4                  NaN     Penny Avila         nathan15@gmail.com  60.0
# 5                  NaN       Todd Cobb       janet82@robinson.com  65.0
# 6                  NaN   Charles Burns        annette97@gmail.com  45.0
# 7                  NaN   Justin Prince       michael12@burke.info  69.0
# 8                  NaN   Brandon Clark  woodardronald@hotmail.com  54.0
# 9                  NaN    Jessica Long     meganpayne@hotmail.com  33.0
#
#                                              Address           Phone Number  \
# 0                                                NaN                    NaN
# 1             1451 Rita Shore\nJohnchester, MT 99947    +1-544-954-3691x582
# 2  2241 Fischer Rest Apt. 195\nNorth Rhondamouth,...       001-526-355-5715
# 3           9143 James Dale\nTammiechester, GA 96987        +1-884-013-8714
# 4             3267 Nicole Spur\nAshleyside, MD 04582  +1-108-431-8484x20444
# 5  0037 Matthew Course Suite 643\nMillsborough, M...             2177347478
# 6  2140 John Valley Suite 470\nWest Jenniferfurt,...     538-517-8315x83296
# 7  2893 Lewis Ports Apt. 546\nPort Rebecca, MD 84050     505.450.7707x14797
# 8         483 Francisco Unions\nNew Steven, DE 39669          (768)466-8295
# 9               242 John View\nNorth Karen, CO 54182             5576057573
#
#                                 Comment       OS
# 0              fuck you and this gameee    Linux
# 1  Seeking stronger storylines in games  Windows
# 2       Need better multiplayer support  Android
# 3  Seeking stronger storylines in games  Android
# 4      Asking for more frequent updates    Linux
# 5          More customizable characters  Android
# 6      Asking for more frequent updates    Linux
# 7     Interested in cross-platform play  Android
# 8     Interested in cross-platform play    macOS
# 9          More customizable characters      iOS

# %%
#look at bottom 10 rows
df.tail(10)
# Out:
#     Timestamp               Name                       Email   Age  \
# 990       NaN      Laurie Walker  johnsonmichele@stewart.com  24.0
# 991       NaN      Donna Stanley        ryansylvia@gmail.com  54.0
# 992       NaN     Pamela Jimenez           dylan62@yahoo.com  62.0
# 993       NaN      Matthew Smith           qbecker@clark.biz  50.0
# 994       NaN     Ronald Swanson     jacobjones@williams.com  40.0
# 995       NaN    Michael Leblanc         kevin88@hotmail.com  36.0
# 996       NaN     Richard Fisher         hansenjade@cole.org  68.0
# 997       NaN      Justin Bright     stevensjeremy@gmail.com  21.0
# 998       NaN     Kevin Williams    marshallmartin@yahoo.com  59.0
# 999       NaN  Jonathan Campbell      munozrobert@martin.com  55.0
#
#                                                Address           Phone Number  \
# 990        58010 Michael Freeway\nWest Jesse, SD 55577             5252877363
# 991      9881 Jamie Shores\nSchroederchester, MN 41369           536.990.1842
# 992  77007 Garner Glen Suite 312\nSamanthaland, SD ...  001-885-182-4853x0340
# 993               549 Beard Manors\nEast Amy, PA 97568      (281)622-5346x749
# 994                   PSC 2384, Box 2112\nAPO AE 88529       573-210-5845x079
# 995      184 Evans Points Apt. 402\nJohnview, MD 29376          (102)850-2519
# 996          1839 Miller Squares\nHardyhaven, NJ 65657          (519)815-3149
# 997      9660 White Hills\nNew Morganchester, NC 82367        +1-256-015-9150
# 998  14359 Andrews Vista Apt. 749\nGutierrezmouth, ...       903.456.3121x016
# 999        13434 Johnson Turnpike\nMeyerside, IL 22613           041.651.9543
#
#                                 Comment       OS
# 990     Looking for diverse game worlds    Linux
# 991    Wish for more realistic graphics  Windows
# 992    Wish for more realistic graphics  Windows
# 993   Interested in cross-platform play  Android
# 994     Want more levels and challenges      iOS
# 995   Interested in cross-platform play      iOS
# 996    Asking for more frequent updates  Windows
# 997  Desire for more strategic gameplay    Linux
# 998        More customizable characters  Windows
# 999    Asking for more frequent updates  Windows

# %%
#lets check the data types of each column
print(df.dtypes)
# Out:
# Timestamp        object
# Name             object
# Email            object
# Age             float64
# Address          object
# Phone Number     object
# Comment          object
# OS               object
# dtype: object

# %%
df_clea
df_cleaned['Zip_Code'] = df_cleaned['Address'][-5:]


df_cleaned.head(5)
# Out:
# <ipython-input-34-9ce99796b5be>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Zip_Code'] = df_cleaned['Address'][-5:]
#              Name                      Email   Age  \
# 1  Heather Savage      alvarezerin@gmail.com  25.0
# 2         Ann Gay  rebeccafleming@wilson.com  54.0
# 3    Rachel Parks   montoyashelley@gmail.com  55.0
# 4     Penny Avila         nathan15@gmail.com  60.0
# 5       Todd Cobb       janet82@robinson.com  65.0
#
#                                              Address           Phone Number  \
# 1              1451 Rita Shore
# Johnchester, MT 99947    +1-544-954-3691x582
# 2  2241 Fischer Rest Apt. 195
# North Rhondamouth, ...       001-526-355-5715
# 3            9143 James Dale
# Tammiechester, GA 96987        +1-884-013-8714
# 4              3267 Nicole Spur
# Ashleyside, MD 04582  +1-108-431-8484x20444
# 5  0037 Matthew Course Suite 643
# Millsborough, MD...             2177347478
#
#                                 Comment                      Comment_Clean  \
# 1  Seeking stronger storylines in games  seeking stronger storylines games
# 2       Need better multiplayer support    need better multiplayer support
# 3  Seeking stronger storylines in games  seeking stronger storylines games
# 4      Asking for more frequent updates            asking frequent updates
# 5          More customizable characters            customizable characters
#
#   sentiment Zip_Code
# 1   Neutral     <NA>
# 2  Positive     <NA>
# 3   Neutral     <NA>
# 4  Positive     <NA>
# 5   Neutral     <NA>

# %%
#lets change the type from object to string for the columns that are necessary & check
df['Name'] = df['Name'].astype('string')
df['Email'] = df['Email'].astype('string')
df['Address'] = df['Address'].astype('string')
df['Phone Number'] = df['Phone Number'].astype('string')
df['Comment'] = df['Comment'].astype('string')

df['Zip_Code'] = df['Address'].str[-5:]
df.head(1000)
# Out:
#                   Name                      Email   Age  \
# 0             jeb bush                       <NA>   NaN
# 1       Heather Savage      alvarezerin@gmail.com  25.0
# 2              Ann Gay  rebeccafleming@wilson.com  54.0
# 3         Rachel Parks   montoyashelley@gmail.com  55.0
# 4          Penny Avila         nathan15@gmail.com  60.0
# ..                 ...                        ...   ...
# 995    Michael Leblanc        kevin88@hotmail.com  36.0
# 996     Richard Fisher        hansenjade@cole.org  68.0
# 997      Justin Bright    stevensjeremy@gmail.com  21.0
# 998     Kevin Williams   marshallmartin@yahoo.com  59.0
# 999  Jonathan Campbell     munozrobert@martin.com  55.0
#
#                                                Address           Phone Number  \
# 0                                                 <NA>                   <NA>
# 1                1451 Rita Shore
# Johnchester, MT 99947    +1-544-954-3691x582
# 2    2241 Fischer Rest Apt. 195
# North Rhondamouth, ...       001-526-355-5715
# 3              9143 James Dale
# Tammiechester, GA 96987        +1-884-013-8714
# 4                3267 Nicole Spur
# Ashleyside, MD 04582  +1-108-431-8484x20444
# ..                                                 ...                    ...
# 995       184 Evans Points Apt. 402
# Johnview, MD 29376          (102)850-2519
# 996           1839 Miller Squares
# Hardyhaven, NJ 65657          (519)815-3149
# 997       9660 White Hills
# New Morganchester, NC 82367        +1-256-015-9150
# 998  14359 Andrews Vista Apt. 749
# Gutierrezmouth, C...       903.456.3121x016
# 999         13434 Johnson Turnpike
# Meyerside, IL 22613           041.651.9543
#
#                                   Comment Zip_Code
# 0                fuck you and this gameee     <NA>
# 1    Seeking stronger storylines in games    99947
# 2         Need better multiplayer support    94239
# 3    Seeking stronger storylines in games    96987
# 4        Asking for more frequent updates    04582
# ..                                    ...      ...
# 995     Interested in cross-platform play    29376
# 996      Asking for more frequent updates    65657
# 997    Desire for more strategic gameplay    82367
# 998          More customizable characters    84355
# 999      Asking for more frequent updates    22613
#
# [1000 rows x 7 columns]

# %%
#check how many rows we have

num_rows = len(df)
print(num_rows)
# Out:
# 1000

# %%
# summary statistics of dataset

df.describe()
# Out:
#               Age
# count  999.000000
# mean    43.822823
# std     15.418856
# min     18.000000
# 25%     30.000000
# 50%     43.000000
# 75%     57.000000
# max     70.000000

# %%
# Summary statistics for numeric columns
print("Summary Statistics for Age:")
print(df['Age'].describe())
# Out:
# Summary Statistics for Age:
# count    999.000000
# mean      43.822823
# std       15.418856
# min       18.000000
# 25%       30.000000
# 50%       43.000000
# 75%       57.000000
# max       70.000000
# Name: Age, dtype: float64

# %%
# Count of unique values in each demographic column
print("\nUnique Values in Demographics:")
print("Unique Names:", df['Name'].nunique())
print("Unique Emails:", df['Email'].nunique())
print("Unique Addresses:", df['Address'].nunique())
print("Unique Phone Numbers:", df['Phone Number'].nunique())
# Out:
# Unique Values in Demographics:
# Unique Names: 991
# Unique Emails: 999
# Unique Addresses: 999
# Unique Phone Numbers: 999

# %%
#Checking for missing values
df.isnull().sum()
# Out:
# Timestamp       999
# Name              0
# Email             1
# Age               1
# Address           1
# Phone Number      1
# Comment           0
# OS                0
# dtype: int64

# %%
#Drop Collumn
df = df.drop('Timestamp', axis=1)

# %%
df.head(10)
# Out:
#              Name                      Email   Age  \
# 0        jeb bush                       <NA>   NaN
# 1  Heather Savage      alvarezerin@gmail.com  25.0
# 2         Ann Gay  rebeccafleming@wilson.com  54.0
# 3    Rachel Parks   montoyashelley@gmail.com  55.0
# 4     Penny Avila         nathan15@gmail.com  60.0
# 5       Todd Cobb       janet82@robinson.com  65.0
# 6   Charles Burns        annette97@gmail.com  45.0
# 7   Justin Prince       michael12@burke.info  69.0
# 8   Brandon Clark  woodardronald@hotmail.com  54.0
# 9    Jessica Long     meganpayne@hotmail.com  33.0
#
#                                              Address           Phone Number  \
# 0                                               <NA>                   <NA>
# 1              1451 Rita Shore
# Johnchester, MT 99947    +1-544-954-3691x582
# 2  2241 Fischer Rest Apt. 195
# North Rhondamouth, ...       001-526-355-5715
# 3            9143 James Dale
# Tammiechester, GA 96987        +1-884-013-8714
# 4              3267 Nicole Spur
# Ashleyside, MD 04582  +1-108-431-8484x20444
# 5  0037 Matthew Course Suite 643
# Millsborough, MD...             2177347478
# 6  2140 John Valley Suite 470
# West Jenniferfurt, ...     538-517-8315x83296
# 7   2893 Lewis Ports Apt. 546
# Port Rebecca, MD 84050     505.450.7707x14797
# 8          483 Francisco Unions
# New Steven, DE 39669          (768)466-8295
# 9                242 John View
# North Karen, CO 54182             5576057573
#
#                                 Comment       OS
# 0              fuck you and this gameee    Linux
# 1  Seeking stronger storylines in games  Windows
# 2       Need better multiplayer support  Android
# 3  Seeking stronger storylines in games  Android
# 4      Asking for more frequent updates    Linux
# 5          More customizable characters  Android
# 6      Asking for more frequent updates    Linux
# 7     Interested in cross-platform play  Android
# 8     Interested in cross-platform play    macOS
# 9          More customizable characters      iOS

# %%
#Dropping rows with NaN (null), saving as a new "cleaned" dataset, and checking that the operation worked
df_cleaned = df.dropna()
df_cleaned.isnull().sum()
# Out:
# Name            0
# Email           0
# Age             0
# Address         0
# Phone Number    0
# Comment         0
# OS              0
# dtype: int64

# %%
df_cleaned.head(20)
# Out:
#                  Name                            Email   Age  \
# 1      Heather Savage            alvarezerin@gmail.com  25.0
# 2             Ann Gay        rebeccafleming@wilson.com  54.0
# 3        Rachel Parks         montoyashelley@gmail.com  55.0
# 4         Penny Avila               nathan15@gmail.com  60.0
# 5           Todd Cobb             janet82@robinson.com  65.0
# 6       Charles Burns              annette97@gmail.com  45.0
# 7       Justin Prince             michael12@burke.info  69.0
# 8       Brandon Clark        woodardronald@hotmail.com  54.0
# 9        Jessica Long           meganpayne@hotmail.com  33.0
# 10        Erik Bowers   tiffanycooke@carter-rogers.net  24.0
# 11        Brent Ayers               david15@potter.com  45.0
# 12      Kathy Walters             brandon63@carter.biz  36.0
# 13     Brian Ferguson          bellchristina@yahoo.com  35.0
# 14       Bryan Powell                 gary17@yahoo.com  32.0
# 15     Angela Schmidt           alexandra17@carter.com  58.0
# 16      Ethan Johnson         denise59@baker-smith.org  24.0
# 17   Shelley Gonzalez  thompsonrobert@jones-salas.info  68.0
# 18  Jeffrey Hernandez          floresjesse@hotmail.com  31.0
# 19       Emily Reilly   crawfordalexis@colon-ross.info  54.0
# 20   Courtney Johnson               kendra88@walsh.net  67.0
#
#                                               Address            Phone Number  \
# 1               1451 Rita Shore
# Johnchester, MT 99947     +1-544-954-3691x582
# 2   2241 Fischer Rest Apt. 195
# North Rhondamouth, ...        001-526-355-5715
# 3             9143 James Dale
# Tammiechester, GA 96987         +1-884-013-8714
# 4               3267 Nicole Spur
# Ashleyside, MD 04582   +1-108-431-8484x20444
# 5   0037 Matthew Course Suite 643
# Millsborough, MD...              2177347478
# 6   2140 John Valley Suite 470
# West Jenniferfurt, ...      538-517-8315x83296
# 7    2893 Lewis Ports Apt. 546
# Port Rebecca, MD 84050      505.450.7707x14797
# 8           483 Francisco Unions
# New Steven, DE 39669           (768)466-8295
# 9                 242 John View
# North Karen, CO 54182              5576057573
# 10             7457 Orr Pine
# West Reneetown, NY 69152            023.778.5618
# 11           109 Kimberly Mills
# Marychester, WV 82113      (542)465-2999x2992
# 12  8258 Delgado Springs Apt. 059
# Lisaborough, NV ...       (615)900-8125x300
# 13  3790 Hughes Pines Apt. 226
# Collinschester, WI ...            623-162-9981
# 14  295 Sparks Ports Apt. 715
# West Joshuatown, CO ...            737-788-5436
# 15           3121 Davidson Hills
# Port Kayla, NV 42590  001-801-210-3605x30256
# 16       50853 Haynes Crossing
# Clementsport, MA 80007      656-985-0879x99608
# 17  649 Jennings Unions Suite 856
# Scottland, SC 92175           (483)505-2530
# 18  374 Montoya Course Suite 064
# Port Margaret, WI...     (209)086-1460x78217
# 19  44273 Marshall Stravenue
# East Terranceland, NC...         +1-049-141-8923
# 20            2300 Nicole Vista
# Spencerview, NH 70046       (262)070-4582x700
#
#                                  Comment       OS
# 1   Seeking stronger storylines in games  Windows
# 2        Need better multiplayer support  Android
# 3   Seeking stronger storylines in games  Android
# 4       Asking for more frequent updates    Linux
# 5           More customizable characters  Android
# 6       Asking for more frequent updates    Linux
# 7      Interested in cross-platform play  Android
# 8      Interested in cross-platform play    macOS
# 9           More customizable characters      iOS
# 10    Desire for more strategic gameplay  Android
# 11     Interested in cross-platform play      iOS
# 12      Wish for more realistic graphics    macOS
# 13      Wish for more realistic graphics  Windows
# 14    Desire for more strategic gameplay      iOS
# 15      Wish for more realistic graphics    macOS
# 16       Want more levels and challenges    Linux
# 17      Wish for more realistic graphics  Windows
# 18      Wish for more realistic graphics      iOS
# 19     Interested in cross-platform play    macOS
# 20       Need better multiplayer support  Android

# %%
#Let's create a new column called "Domain" which will show what email domain a person is using

df_cleaned['Domain'] = df_cleaned['Email'].apply(lambda x: x.split('@')[1])
df_cleaned.head(10)
# Out:
# <ipython-input-17-dd892369ff13>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Domain'] = df_cleaned['Email'].apply(lambda x: x.split('@')[1])
#               Name                           Email   Age  \
# 1   Heather Savage           alvarezerin@gmail.com  25.0
# 2          Ann Gay       rebeccafleming@wilson.com  54.0
# 3     Rachel Parks        montoyashelley@gmail.com  55.0
# 4      Penny Avila              nathan15@gmail.com  60.0
# 5        Todd Cobb            janet82@robinson.com  65.0
# 6    Charles Burns             annette97@gmail.com  45.0
# 7    Justin Prince            michael12@burke.info  69.0
# 8    Brandon Clark       woodardronald@hotmail.com  54.0
# 9     Jessica Long          meganpayne@hotmail.com  33.0
# 10     Erik Bowers  tiffanycooke@carter-rogers.net  24.0
#
#                                               Address           Phone Number  \
# 1               1451 Rita Shore
# Johnchester, MT 99947    +1-544-954-3691x582
# 2   2241 Fischer Rest Apt. 195
# North Rhondamouth, ...       001-526-355-5715
# 3             9143 James Dale
# Tammiechester, GA 96987        +1-884-013-8714
# 4               3267 Nicole Spur
# Ashleyside, MD 04582  +1-108-431-8484x20444
# 5   0037 Matthew Course Suite 643
# Millsborough, MD...             2177347478
# 6   2140 John Valley Suite 470
# West Jenniferfurt, ...     538-517-8315x83296
# 7    2893 Lewis Ports Apt. 546
# Port Rebecca, MD 84050     505.450.7707x14797
# 8           483 Francisco Unions
# New Steven, DE 39669          (768)466-8295
# 9                 242 John View
# North Karen, CO 54182             5576057573
# 10             7457 Orr Pine
# West Reneetown, NY 69152           023.778.5618
#
#                                  Comment       OS             Domain
# 1   Seeking stronger storylines in games  Windows          gmail.com
# 2        Need better multiplayer support  Android         wilson.com
# 3   Seeking stronger storylines in games  Android          gmail.com
# 4       Asking for more frequent updates    Linux          gmail.com
# 5           More customizable characters  Android       robinson.com
# 6       Asking for more frequent updates    Linux          gmail.com
# 7      Interested in cross-platform play  Android         burke.info
# 8      Interested in cross-platform play    macOS        hotmail.com
# 9           More customizable characters      iOS        hotmail.com
# 10    Desire for more strategic gameplay  Android  carter-rogers.net

# %% [markdown]
# ## EDA Visualizations

# %%
#plotting Age
import matplotlib.pyplot as plt
plt.hist(df_cleaned['Age'], bins=12, edgecolor='k', alpha=0.9)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution Histogram')
plt.grid(False)
plt.show()

# %%
#create scatter plot of age
age_counts = df_cleaned['Age'].value_counts()

# Creating a scatter plot
plt.scatter(age_counts.index, age_counts.values)
plt.title('Age Count Scatter Plot')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Let's find out what the most common email domain is

# Counting occurrences of each domain
domain_counts = df_cleaned['Domain'].value_counts()

# Creating a pie chart
plt.pie(domain_counts, labels=domain_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Domains')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Domain'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-45bc3c7880d1> in <cell line: 4>()
#       2
#       3 # Counting occurrences of each domain
# ----> 4 domain_counts = df_cleaned['Domain'].value_counts()
#       5
#       6 # Creating a pie chart
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Domain'

# %%
column_description = df_cleaned['Domain'].describe()
print(column_description)

# %% [markdown]
# ##Tokenization

# %% [markdown]
# Text preprocessing is essential to clean and prepare the text data for analysis. For this step we will apply the following:
# a. Removing Punctuation:
#
# 1.   Remove any special characters and punctuation marks from the Comment column
# 2.   Lowercasing: Convert all text to lowercase to ensure consistency.
# 3.   Removing Stopwords: Remove common stopwords (e.g., 'the', 'and', 'in') that don't carry much meaning.

# %%
# imports needed for NLP
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Here we are creating a function that is removing punctuation, then lowercasing words, then removing stop words

# Define a function to preprocess text
def preprocess_text(text):
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    text = text.lower()

    # Tokenize the text
    words = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    return ' '.join(words)

# Creating a new column in our data set called 'Comment_Clean' which represent the tokenized and processed text
df_cleaned['Comment_Clean'] = df_cleaned['Comment'].apply(preprocess_text)
# Out:
# <ipython-input-17-57b5fedee593>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Comment_Clean'] = df_cleaned['Comment'].apply(preprocess_text)

# %%
#check to verfiy above steps worked correctly
df_cleaned.head(10)
# Out:
#               Name                           Email   Age  \
# 1   Heather Savage           alvarezerin@gmail.com  25.0
# 2          Ann Gay       rebeccafleming@wilson.com  54.0
# 3     Rachel Parks        montoyashelley@gmail.com  55.0
# 4      Penny Avila              nathan15@gmail.com  60.0
# 5        Todd Cobb            janet82@robinson.com  65.0
# 6    Charles Burns             annette97@gmail.com  45.0
# 7    Justin Prince            michael12@burke.info  69.0
# 8    Brandon Clark       woodardronald@hotmail.com  54.0
# 9     Jessica Long          meganpayne@hotmail.com  33.0
# 10     Erik Bowers  tiffanycooke@carter-rogers.net  24.0
#
#                                               Address           Phone Number  \
# 1               1451 Rita Shore
# Johnchester, MT 99947    +1-544-954-3691x582
# 2   2241 Fischer Rest Apt. 195
# North Rhondamouth, ...       001-526-355-5715
# 3             9143 James Dale
# Tammiechester, GA 96987        +1-884-013-8714
# 4               3267 Nicole Spur
# Ashleyside, MD 04582  +1-108-431-8484x20444
# 5   0037 Matthew Course Suite 643
# Millsborough, MD...             2177347478
# 6   2140 John Valley Suite 470
# West Jenniferfurt, ...     538-517-8315x83296
# 7    2893 Lewis Ports Apt. 546
# Port Rebecca, MD 84050     505.450.7707x14797
# 8           483 Francisco Unions
# New Steven, DE 39669          (768)466-8295
# 9                 242 John View
# North Karen, CO 54182             5576057573
# 10             7457 Orr Pine
# West Reneetown, NY 69152           023.778.5618
#
#                                  Comment       OS             Domain  \
# 1   Seeking stronger storylines in games  Windows          gmail.com
# 2        Need better multiplayer support  Android         wilson.com
# 3   Seeking stronger storylines in games  Android          gmail.com
# 4       Asking for more frequent updates    Linux          gmail.com
# 5           More customizable characters  Android       robinson.com
# 6       Asking for more frequent updates    Linux          gmail.com
# 7      Interested in cross-platform play  Android         burke.info
# 8      Interested in cross-platform play    macOS        hotmail.com
# 9           More customizable characters      iOS        hotmail.com
# 10    Desire for more strategic gameplay  Android  carter-rogers.net
#
#                         Comment_Clean
# 1   seeking stronger storylines games
# 2     need better multiplayer support
# 3   seeking stronger storylines games
# 4             asking frequent updates
# 5             customizable characters
# 6             asking frequent updates
# 7       interested crossplatform play
# 8       interested crossplatform play
# 9             customizable characters
# 10          desire strategic gameplay

# %%
# Here we will create a frequency count of the most common words

from nltk import FreqDist
from nltk.tokenize import word_tokenize

# Tokenize the 'comment_clean' column and compute word frequencies
word_frequencies = FreqDist(word_tokenize(' '.join(df_cleaned['Comment_Clean'])))

# Display the word frequencies
print("Word Frequencies:")
for word, frequency in word_frequencies.items():
    print(f"{word}: {frequency}")
# Out:
# Word Frequencies:
# seeking: 1006
# stronger: 1006
# storylines: 1006
# games: 1006
# need: 998
# better: 998
# multiplayer: 998
# support: 998
# asking: 980
# frequent: 980
# updates: 980
# customizable: 993
# characters: 993
# interested: 990
# crossplatform: 990
# play: 990
# desire: 999
# strategic: 999
# gameplay: 999
# wish: 1021
# realistic: 1021
# graphics: 1021
# want: 1011
# levels: 1011
# challenges: 1011
# hoping: 1023
# virtual: 1023
# reality: 1023
# compatibility: 1023
# looking: 978
# diverse: 978
# game: 978
# worlds: 978

# %%
# visualize word frequency
from wordcloud import WordCloud
import  matplotlib.pyplot as plt




# Tokenize the 'Comment_Clean' column and compute word frequencies
words = word_tokenize(' '.join(df_cleaned['Comment_Clean']))
word_frequencies = FreqDist(words)

# Create a word cloud from the word frequencies
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_frequencies)

# Display the word cloud using Matplotlib
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("GTA 666 User Comments Word Cloud")
plt.show()

# %%
# Create a DataFrame from the word frequencies
df_word_count = pd.DataFrame({'Word': list(word_frequencies.keys()), 'Word_Count': list(word_frequencies.values())})

df_word_count.head(10)
# Out:
#           Word  Word_Count
# 0      seeking        1006
# 1     stronger        1006
# 2   storylines        1006
# 3        games        1006
# 4         need         998
# 5       better         998
# 6  multiplayer         998
# 7      support         998
# 8       asking         980
# 9     frequent         980
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Word_Count'].plot(kind='hist', bins=20, title='Word_Count')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Word_Count'].plot(kind='line', figsize=(8, 4), title='Word_Count')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ##Sentiment Analysis

# %%
from textblob import TextBlob

# Load your DataFrame with tokenized and cleaned text (assuming it's already loaded as 'df')

# Define a function for sentiment analysis using TextBlob
def analyze_sentiment(text):
    analysis = TextBlob(text)
    # Assign sentiment labels based on polarity
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

# Apply sentiment analysis to the 'comment_clean' column and store results in a new column
df_cleaned['sentiment'] = df_cleaned['Comment_Clean'].apply(analyze_sentiment)

# Count the sentiment categories
sentiment_counts = df_cleaned['sentiment'].value_counts()

# Print sentiment distribution
print("Sentiment Distribution:")
print(sentiment_counts)

# You can also visualize the sentiment distribution using libraries like Matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sentiment_counts.plot(kind='bar', color=['green', 'red', 'blue'])
plt.title('Sentiment Distribution of Comments')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()
# Out:
# <ipython-input-31-61a585832eab>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['sentiment'] = df_cleaned['Comment_Clean'].apply(analyze_sentiment)
# Sentiment Distribution:
# Neutral     5032
# Positive    3989
# Negative     978
# Name: sentiment, dtype: int64
